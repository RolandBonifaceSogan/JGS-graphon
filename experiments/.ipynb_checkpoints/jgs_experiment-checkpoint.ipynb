# %%
#Autres modules importants à utiliser
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from typing import Dict, List, Tuple, Any, Optional
import os
import sys
import pickle
import time
from skimage.restoration import denoise_tv_chambolle

# %%
# !git clone https://github.com/ahxt/g-mixup.git
# %cd g-mixup
# Out:
# Clonage dans 'g-mixup'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 16 (delta 3), reused 11 (delta 1), pack-reused 0 (from 0)
# Réception d'objets: 100% (16/16), 1.69 Mio | 3.66 Mio/s, fait.
# Résolution des deltas: 100% (3/3), fait.
# /home/rbsogan/Documents/THESE/AIstat/JGS-graphon/experiments/g-mixup
# /home/rbsogan/SIGL/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
import sys

# Récupère le chemin absolu du projet
project_root = os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))
gmixup_src = os.path.join(project_root, 'experiments', 'g_mixup', 'src')

# Ajoute les chemins au PYTHONPATH
for p in [project_root, gmixup_src]:
    if p not in sys.path:
        sys.path.insert(0, p)

# Maintenant, tu peux importer :
from utils import *
#from mixup_train import *
#from stat_graph import *
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 import sys
#       4 # Récupère le chemin absolu du projet
# ----> 5 project_root = os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))
#       6 gmixup_src = os.path.join(project_root, 'experiments', 'g_mixup', 'src')
#       8 # Ajoute les chemins au PYTHONPATH
#
# NameError: name '__file__' is not defined

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u /home/rbsogan/Documents/THESE/AIstat/JGS-graphon/experiments/jgs_gmixup.py --data_path . --model GIN --dataset IMDB-BINARY \
  --lr 0.01 --gmixup True --seed 1314 --log_screen True --batch_size 128 --num_hidden 64 \
  --aug_ratio 0.2 --aug_num 10 --ge USVT > log_file_binary_1314.txt 2>&1

# %%
# !pip install googledrivedownloader
# Out:
# Requirement already satisfied: googledrivedownloader in /home/rbsogan/SIGL/venv/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: requests in /home/rbsogan/SIGL/venv/lib/python3.10/site-packages (from googledrivedownloader) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/rbsogan/SIGL/venv/lib/python3.10/site-packages (from requests->googledrivedownloader) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/rbsogan/SIGL/venv/lib/python3.10/site-packages (from requests->googledrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/rbsogan/SIGL/venv/lib/python3.10/site-packages (from requests->googledrivedownloader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rbsogan/SIGL/venv/lib/python3.10/site-packages (from requests->googledrivedownloader) (2025.8.3)

# %%
import sys
print(sys.executable)
# Out:
# /home/rbsogan/SIGL/venv/bin/python3

# %%
import torch_geometric.datasets as datasets
print(datasets.__file__)
# Out:
# /home/rbsogan/SIGL/venv/lib/python3.10/site-packages/torch_geometric/datasets/__init__.py

# %%
# === IMPORT DES MODULES ===
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GCNConv, global_mean_pool
import networkx as nx
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# === VÉRIFICATION DES VERSIONS ===
print(f"PyTorch: {torch.__version__}")
print(f"Torch Geometric: {torch.__version__}")
print(f"NetworkX: {nx.__version__}")
# Out:
# PyTorch: 1.13.1+cpu
# Torch Geometric: 1.13.1+cpu
# NetworkX: 3.4.2

# %%
module_path = os.path.abspath(os.path.join('..', 'g-mixup/src'))
if module_path not in sys.path:
    sys.path.insert(0, module_path)
